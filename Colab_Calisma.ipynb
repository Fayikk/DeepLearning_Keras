# %% [markdown]
# <a href="https://colab.research.google.com/github/Fayikk/DeepLearning_Keras/blob/master/Colab_Calisma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Google Colab Çalışma Ortamı
#
# Collaboraty veya kısaca 'Colab' tarayıcınızı kullanarak python dilinde uygulamalarınızı yapmaya olanak tanır.
#
# # Kuruluma ihtiyaç yoktur
# # gpu VE TPU'lara ücretsiz erişim sağlar.
# # Ortak çalışma imkanı sunar

# %%
print("Hello My Galaxy")
# Out:
# Hello My Galaxy

# %% [markdown]
# ## CPU hakkında

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# ...

# %% [markdown]
# ## Ram hakkında

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13298580 kB
# MemFree:        10798164 kB
# MemAvailable:   12470464 kB
# Buffers:          108136 kB
# Cached:          1706284 kB
# SwapCached:            0 kB
# Active:           985976 kB
# Inactive:        1332020 kB
# Active(anon):     446264 kB
# Inactive(anon):      456 kB
# Active(file):     539712 kB
# Inactive(file):  1331564 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               628 kB
# Writeback:             0 kB
# AnonPages:        503556 kB
# Mapped:           228072 kB
# Shmem:              1200 kB
# KReclaimable:      84952 kB
# Slab:             126920 kB
# SReclaimable:      84952 kB
# SUnreclaim:        41968 kB
# KernelStack:        4768 kB
# PageTables:         7556 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6649288 kB
# Committed_AS:    3044492 kB
# VmallocTotal:   34359738367 kB
# ...

# %% [markdown]
# ## VERİ BİLİMİ
# Veri bilimi için `Python`'ın farklı kütüphanelerini colab ortamında kullnarak ve görselleştirme.İşlemleride yapabiliriz.
#
# `Numpy` ve `Matplotlib` kütüphanelerini kullanark bir görselleştirme yapalım.

# %%
import numpy as np
from matplotlib import pyplot as plt

ys=50 + np.random.randn(50)
x = [x for x in range (len(ys))]
plt.plot(x,ys,".")
plt.fill_between(x,ys, 45,where =(ys >45),facecolor='m',alpha=0.5)

plt.title("Örnek Gösterim")
plt.show()

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x=alt.X('Miles_per_Gallon', bin=True),
  y='count()',
  color='Origin'
)
# Out:
# alt.Chart(...)

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_point().encode(
  x='Horsepower',
  y='Miles_per_Gallon',
  color='Origin'
).interactive()

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x='mean(Miles_per_Gallon)',
  y='Origin',
  color='Origin'
)
# Out:
# alt.Chart(...)

# %%
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# ...

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_point().encode(
  x='Horsepower',
  y='Miles_per_Gallon',
  color='Origin'
).interactive()
# Out:
# alt.Chart(...)

# %%
from google.colab import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %% [markdown]
# # Kütüphane kurulumları

# %%
# !pip install -q keras
import keras

# %%
# !apt-get install graphviz -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# graphviz is already the newest version (2.40.1-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %% [markdown]
# # #GPU özelliklerinin görüntülenmesi.

# %%
 import tensorflow as tf
 tf.test.qpu_device_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-f8e31198e766> in <module>()
#       1 import tensorflow as tf
# ----> 2 tf.test.qpu_device_name()
#
# AttributeError: module 'tensorflow._api.v2.test' has no attribute 'qpu_device_name'

# %%
import tensorflow_hub as hub

# %%
print("TF version: ",tf.__version__)
print("Hub version: ", hub.__version__)
print("GPU is , 'available'" if tf.test.is_gpu_available() else "not available")
# Out:
# TF version:  2.8.2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-460e5747908d> in <module>()
#       1 print("TF version: ",tf.__version__)
# ----> 2 print("Hub version: ", hub.__version__)
#       3 print("GPU is , 'available'" if tf.test.is_gpu_available() else "not available")
#
# NameError: name 'hub' is not defined

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 15495226589903622721
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14444920832
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 5171834669946775365
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
#  xla_global_id: 416903419]

# %%
# !python3 rakam_tanıma_CNN_MNIST.py
# Out:
# python3: can't open file 'rakam_tanıma_CNN_MNIST.py': [Errno 2] No such file or directory

# %%
# !python3 rakam_tanima_CNN_MNIST.py
# Out:
# python3: can't open file 'rakam_tanima_CNN_MNIST.py': [Errno 2] No such file or directory

# %%
# !ls
# Out:
# sample_data

# %%
# !kill -9 -1

# %%
from google.colab import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !ls "/gdrive/Drive'ım/Calisma_Ortami/"
# Out:
# ls: cannot access "/gdrive/Drive'ım/Calisma_Ortami/": No such file or directory

# %%
# !python3 rakam_tanima_CNN_MNIST.py
# Out:
# python3: can't open file 'rakam_tanima_CNN_MNIST.py': [Errno 2] No such file or directory
